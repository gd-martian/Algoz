# %%
def make_tea():
    print("Step 1: Boil water")
    print("Step 2: Put teabag in cup")
    print("Step 3: Pour water into cup")
    print("Step 4: Wait 3 minutes")
    print("Step 5: Remove teabag")
    print("Step 6: Add sugar if needed")

make_tea()
# Out:
# Step 1: Boil water
# Step 2: Put teabag in cup
# Step 3: Pour water into cup
# Step 4: Wait 3 minutes
# Step 5: Remove teabag
# Step 6: Add sugar if needed

# %%
def make_tea():
    print("Step 1: Boil water")
    print("Step 2: Put teabag in cup")
    print("Step 3: Pour water into cup")
    print("Step 4: Wait 3 minutes")
    print("Step 5: Remove teabag")
    print("Step 6: Add sugar if needed")

make_tea()
# Out:
# Step 1: Boil water
# Step 2: Put teabag in cup
# Step 3: Pour water into cup
# Step 4: Wait 3 minutes
# Step 5: Remove teabag
# Step 6: Add sugar if needed

# %%
print
# Out:
# <built-in function print>

# %%
def make_tea():
    print("Step 1: Boil water")
    print("Step 2: Put teabag in cup")
    print("Step 3: Pour water into cup")
    print("Step 4: Wait 3 minutes")
    print("Step 5: Remove teabag")
    print("Step 6: Add sugar if needed")

make_tea()
# Out:
# Step 1: Boil water
# Step 2: Put teabag in cup
# Step 3: Pour water into cup
# Step 4: Wait 3 minutes
# Step 5: Remove teabag
# Step 6: Add sugar if needed

# %%
def water():
  print("Step 1: Boil")
  print("Step 2: Pour in cup")
  print("Step 3: Drink")

water()
# Out:
# Step 1: Boil
# Step 2: Pour in cup
# Step 3: Drink

# %%
print("Enjoy your tea")
# Out:
# Enjoy your tea

# %%
name= "Alice"
age = 25
height = 5.9
is_student = True

print("Name:",name)
print("Age:",age)
print("Height:",height)
print("Is a student?",is_student)
# Out:
# Name: Alice
# Age: 25
# Height: 5.9
# Is a student? True
